# %% [markdown]
# # Moody's Risk Calc-API Data Input
# The purpose of this program is the replace the manual scoring process currently implemented into a more automated process. This will enable the end user more ease and more accuracy in creating the monthly scores for all new and exiting principals, both currently and all previous months.¶

# %%
import sharepy, getpass, json, os, pandas as pd, numpy as np
from datetime import datetime
pd.set_option("display.max_columns", None)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Step 1: Data Call
# Make sure the naming convention's listed in red match exactly with what the name of the GIBSS files are listed as.
#
# Also make sure to update your n-number under the "project root" for file location
#
# # File locations and names must match EXACTLY

# %%
#since all 6 datasets must be treated in the same manner, i will load all 6 and run through the same process concurrently
project_root='C:/Users/n1564120/Downloads'
Stated='Stated'
Adjusted='Adjusted'
comst=pd.read_excel(project_root+ '/FAW Commercial Stated Report.xlsx')
comst.insert(loc=24, column='Pilot?', value=Stated)
comad=pd.read_excel(project_root+'/FAW Commercial Adjusted Report.xlsx')
comad.insert(loc=24, column='Pilot?', value=Adjusted)
const=pd.read_excel(project_root+'/FAW Contract  Stated Reports.xlsx')
const.insert(loc=24, column='Pilot?', value=Stated)
conad=pd.read_excel(project_root+'/FAW Contract  AdjustedReports.xlsx')
conad.insert(loc=24, column='Pilot?', value=Adjusted)
inad=pd.read_excel(project_root+'/FAW National-International Adjusted Reports.xlsx')
inad.insert(loc=24, column='Pilot?', value=Adjusted)
inst=pd.read_excel(project_root+'/FAW National-International Stated Reports.xlsx')
inst.insert(loc=24, column='Pilot?', value=Stated)

#ref/lookup table file, not to be merged
#mp=pd.read_csv('C:/Users/n1564120/OneDrive - Liberty Mutual/Documents/mappingtable.csv', header=0)

# %% [markdown]
# ###  Combine the 6 GIBSS files

# %%
#create the consolidated FAW file, beginning with the common element columns
df = comst.append([comad, const, conad, inad, inst])

# %% [markdown]
# ### Create Date Fields for Common Data Elements

# %%
#complete the statement date and current date common element columns
df.fillna(0)
df['Datadate']=pd.to_datetime(df['Datadate'], format='%m/%d/%Y')
df['Statement Date - Year']=df['Datadate'].dt.year
df['Statement Date - Month']=df['Datadate'].dt.month
currentDatetime=datetime.now()
date=currentDatetime.date()
df['Current Date - Year']=date.strftime('%Y')
df['Current Date - Month']=date.strftime('%m')
df['Current Date - Day']=date.strftime('%d')
df['Prior Year']=(df['Statement Date - Year']-1)
df['Current Date']=np.datetime64('today')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
df.info(verbose=True, null_counts=True)
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52089 entries, 0 to 9645
# Data columns (total 262 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              51926 non-null  float64
#  1   Account Name                                                            51926 non-null  object
#  2   Principal ID                                                            52089 non-null  int64
#  3   Principal Name                                                          52089 non-null  object
#  4   Principal that Represents the Account                                   51926 non-null  float64
#  5   Account Office                                                          51926 non-null  object
# ...

# %% [markdown]
# ## Run Initial Filters
#
# ### These filters include
#
# whether a Product Segment is Core Commercial, Core Contract, Specialty Commercial or Specialty Contract. There is a second filter that eliminates ANY core contract where the Account Office is US Based
#
# Whether the statment period equals "12"
#
# Whether the statement Type is Review, Qualified Audit or Unqualified Audit

# %%
df2=df.copy()

df2['Combined']= df2["Pilot?"].str.cat(df2[["Principal ID", "Datadate", 'Template Type', 'Statement Type', 'FAW ID']].astype(str), sep="_")

# %%
df1=df2[(df2['Product Segment']=='Core Commercial') | (df2['Product Segment']=='Core Contract')|
        (df2['Product Segment']=='Specialty Commercial')|(df2['Product Segment']=='Specialty Contract')]


df14=df1[df1['Statement Type'].isin(['Review', 'Qualified Audit', 'Unqualified Audit'])]

#remove entries where statement period DNE 12
df15=(df14.loc[df14['Statement Period']==12])

# %%
df15.head()
# Out:
#     Account ID                       Account Name  Principal ID  \
# 57         5.0                      Meritor, Inc.     596321812
# 68         5.0                      Meritor, Inc.     596321812
# 73         5.0                      Meritor, Inc.     596321812
# 78         5.0                      Meritor, Inc.     596321812
# 79         7.0  International Game Technology plc     746530312
#
#                        Principal Name  Principal that Represents the Account  \
# 57                       Meritor Inc.                                    1.0
# 68                       Meritor Inc.                                    1.0
# 73                       Meritor Inc.                                    1.0
# 78                       Meritor Inc.                                    1.0
# 79  International Game Technology PLC                                    1.0
#
#    Account Office   Datadate         Country   Currency      Units  \
# ...

# %%
df39=(df15.loc[df15['Account Office'].isin(['Minneapolis', 'Chicago', 'New York', 'Dallas', 'Atlanta',
       'Philadelphia', 'Kansas City', 'San Francisco', 'Los Angeles',
       'Seattle', 'Orlando', 'Baltimore', 'Wausau', 'Boston',
       'Louisville', 'Charlotte', 'Warrenville', 'Syracuse', 'Cincinnati',
       'Phoenix', 'Hoffman Estates', 'National Bond Center', 'Pittsburgh',
       'Houston', 'Oklahoma City', 'Harrisburg', 'Jackson', 'Home Office',
       'Denver', 'St. Louis', 'St.Pete', 'Vista', 'San Diego',
        'Detroit', 'Irvine', 'ICU', 'Miami - US'])])
df40=(df39.loc[df39['Product Segment']=='Core Contract'])
dfmerge=df40.copy()
dfmerge=(df15[~df15['Principal ID'].isin(df40['Principal ID'])])
dfmerge["Combinedfilter"] = dfmerge["Pilot?"].str.cat(dfmerge[["Principal ID", "Datadate", 'Template Type', 'Statement Type', 'FAW ID']].astype(str), sep="_")
# Out:
# <ipython-input-8-167db2599ce1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmerge["Combinedfilter"] = dfmerge["Pilot?"].str.cat(dfmerge[["Principal ID", "Datadate", 'Template Type', 'Statement Type', 'FAW ID']].astype(str), sep="_")

# %% [markdown]
# ## The code below will output an excel file of all the data we wish to keep after we have filtered the data

# %%
with pd.ExcelWriter('Initial Data filter StatementPd_Product_StateType.xlsx') as writer:
    dfmerge.to_excel(writer, sheet_name='Data Filtered')

# %% [markdown]
# ## The code below will output an excel file of all rows of data that were exclude from the dataframe for the following filters:
#  >Statement Month DNE 12
#
#  >product segment is not core commercial,core contract outside the US, specialty commercial or specialty contract
#
#  >statement type is not Review, Qualified Audit or Unqualified Audit

# %%
dfexclude=df2.merge(dfmerge.drop_duplicates() , how="left", left_on='Combined', right_on='Combinedfilter', indicator=True)

# %%
with pd.ExcelWriter('FilteredOut_StateType_ProdTypeState_Date Data.xlsx') as writer:
    dfexclude.to_excel(writer, sheet_name='Data Filtered')

# %% [markdown]
# ### raj to map in the account office/country lookup

# %%
dfmerge['Country']=dfmerge['Account Office'].map({
'Singapore':'Singapore',
'Sydney':'Australia',
'Hong Kong':'China',
'Calgary':'Canada',
'Toronto':'Canada',
'Vancouver':'Canada',
'Montreal':'Canada',
'Dallas':'United States',
'Denver':'United States',
'Houston':'United States',
'Kansas City':'United States',
'Cologne':'Germany',
'London':'United Kingdom',
'The Hague':'United States',
'Paris':'United Kingdom',
'Milan':'Italy',
'Madrid':'Spain',
'Home Office':'United States',
'National Bond Center':'United States',
'Bogota':'Colombia',
'Guadalajara':'Mexico',
'Mexico City':'Mexico',
'Miami - International':'Mexico',
'Miami - US':'United States',
'Monterrey':'Mexico',
'Santiago':'Chile',
'Sao Paulo':'Mexico',
'Chicago':'United States',
'Cincinnati':'United States',
'Detroit':'United States',
'Hoffman Estates':'United States',
'Minneapolis':'United States',
'St. Louis':'United States',
'Boston':'United States',
'New York':'United States',
'Philadelphia':'United States',
'Pittsburgh':'United States',
'Atlanta':'United States',
'Baltimore':'United States',
'Charlotte':'United States',
'Orlando':'United States',
'San Francisco':'United States',
'Seattle':'United States',
'Los Angeles':'United States',
'Phoenix':'United States',
'Warrenville':'United States',
'Wausau':'United States',
'Marlton':'United States',
'Indianapolis':'United States',
'Columbus':'United States',
'Lima':'Peru',
'Sao Paulo':'Brazil'})
# Out:
# <ipython-input-9-0b3b1b0799a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmerge['Country']=dfmerge['Account Office'].map({

# %%
dfmerge.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33453 entries, 57 to 9644
# Data columns (total 264 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              33387 non-null  float64
#  1   Account Name                                                            33387 non-null  object
#  2   Principal ID                                                            33453 non-null  int64
#  3   Principal Name                                                          33453 non-null  object
#  4   Principal that Represents the Account                                   33387 non-null  float64
#  5   Account Office                                                          33387 non-null  object
# ...

# %% [markdown]
# # Output Excel File to Map in Analyzed Sector, ERM Sector & ERM ID

# %% [markdown]
# ## The code below will upload the updated Mapping Table D and Merge all of the new changes to Python

# %%
mappingtableD=pd.read_excel(project_root+'/8.1.22 Mapping Table D.xlsx')
mergedmap=dfmerge.merge(mappingtableD, on="Principal ID", how='left')

# %%
mappingtableD.head()
# Out:
#    Key  Principal ID                                     Principal Name  \
# 0    3   976425112.0  MUFG Americas Holdings Corporation (formerly U...
# 1    4   911819742.0                              MUFG Union Bank, N.A.
# 2    5    65116151.0                                COELHO MEAT COMPANY
# 3    6   109164132.0  Yakima Valley Memorial Hospital Association db...
# 4    7    96508312.0                        Lehigh Hanson North America
#
#    Account ID from IT                                       Account Name  \
# 0            100350.0  MUFG Americas Holdings Corporation (formerly U...
# 1            208155.0                 MUFG Americas Holdings Corporation
# 2             99501.0                                COELHO MEAT COMPANY
# 3            101281.0                       Virginia Mason Health System
# 4            120780.0                                Lehigh Hanson, Inc.
#
#   Does Principal Exist? Remove From Scoring?              ERM Sector  \
# ...

# %% [markdown]
# ## This is the file that reads the FX Rate into the data

# %%
fx=pd.read_excel(project_root+"/FX Rate.xlsx")
dfmerge_=mergedmap.merge(fx, left_on='Currency', right_on='Currency', how='left')
dfmerge_['ISO Country']=dfmerge_['ISO Currency Code']

# %%
with pd.ExcelWriter('Mapping Table D Merge Manual Input.xlsx') as writer:
    result_df.to_excel(writer, sheet_name='Data Filtered')

# %%
dfmerge_ = dfmerge_[dfmerge_.columns.drop(list(dfmerge_.filter(regex='_y')))]
result_df=dfmerge_.drop_duplicates(subset=['Combinedfilter'], keep='first')

# %%
## ERM Custom Fields


result_df["Assets in $ USD"]=(result_df['Assets']*result_df["FX Rate (As of Dec 2019)"])



#Principal ID + Previous Year + As Stated or As Adjusted #need to 

result_df['Principal ID + Year']=result_df['Principal ID'].astype(str)+ result_df['Prior Year'].astype(str)+result_df['Pilot?']

result_df['Principal ID + Previous Year']=result_df['Principal ID'].astype(str)+result_df['Statement Date - Year'].astype(str)+result_df['Pilot?']

#Max total asset value in USD
result_df['Max Total Asset Value in USD']=result_df.groupby('Principal ID')['Assets in $ USD'].transform('max')
result_df


#Max Statement Year
result_df['Max FYE']=result_df.groupby('Principal ID')['Statement Date - Year'].transform('max')

result_df['Max FYE Date']=result_df.groupby('Principal ID')['Datadate'].transform('max')

#Analyzed Currency
#mappingtableb=pd.read_csv(project_root+'/mappingtableb.csv')
#df6=df.merge(mappingtable2, on='Currency', how= 'left')
result_df['Analyzed Currency']=result_df['ISO Country']


#df19.drop_duplicates(subset = ['Principal ID', 'Account ID'], inplace=True)
#df_a=result_df.copy()
#df__=df_a.merge(mappingtable2, left_on=['Analyzed Country','Asset Category','Country & Asset Category'],right_on=['ISO Country', 'Asset Category','Country & Asset Category'], how='left')
#df['Model']=df__['Risk Calc Model 2.0']

result_df["User-Defined Time Period (optional)"]=1
result_df['ERM ID']=''
result_df['ERM Sector']=''
result_df['Analyzed Sector']=""
# Out:
# <ipython-input-13-4c24a7544dca>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df["Assets in $ USD"]=(result_df['Assets']*result_df["FX Rate (As of Dec 2019)"])
# <ipython-input-13-4c24a7544dca>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['Principal ID + Year']=result_df['Principal ID'].astype(str)+ result_df['Prior Year'].astype(str)+result_df['Pilot?']
# <ipython-input-13-4c24a7544dca>:12: SettingWithCopyWarning:
# ...

# %%
result_df['Country'].unique()
# Out:
# array(['United States', nan, 'Canada', 'Brazil', 'Mexico',
#        'United Kingdom', 'Germany', 'Spain', 'Colombia', 'China', 'Peru',
#        'Chile', 'Australia', 'Italy', 'Singapore'], dtype=object)

# %%
#Asset Category
conditions=[
    (result_df['Max Total Asset Value in USD']<=55000000),
    (result_df['Max Total Asset Value in USD']>55000000)&(result_df['Max Total Asset Value in USD']<=100000000),
    (result_df['Max Total Asset Value in USD']>100000000)]
values=['Below $55M', '> $55M', '> $100M']
result_df['Asset Category']=np.select(conditions, values)

#Analyzed Country
result_df['Analyzed Country']=result_df['ISO Country']

#Country + Asset Category
result_df['Country + Asset Category']=result_df['Analyzed Country']+result_df['Asset Category']
# Out:
# <ipython-input-14-674ed784d460>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['Asset Category']=np.select(conditions, values)
# <ipython-input-14-674ed784d460>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['Analyzed Country']=result_df['ISO Country']
# <ipython-input-14-674ed784d460>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Raj to include the risk calc excel document

# %%
result_df['Risk Calc Model 2.0']=result_df['Country + Asset Category'].map({'ARG> $100M':'Emerging Markets',
'ARG> $55M':'Emerging Markets',
'ARGBelow $55M':'Emerging Markets',
'AUS> $100M':'Australia',
'AUS> $55M':'Australia',
'AUSBelow $55M':'Australia',
'AUT> $100M':'Europe Large Firm',
'AUT> $55M':'Europe Large Firm',
'AUTBelow $55M':'Europe Large Firm',
'BHS> $100M':'Emerging Markets',
'BHS> $55M':'Emerging Markets',
'BHSBelow $55M':'Emerging Markets',
'BEL> $100M':'Europe Large Firm',
'BEL> $55M':'Europe Large Firm',
'BELBelow $55M':'Europe Large Firm',
'BMU> $100M':'Emerging Markets',
'BMU> $55M':'Emerging Markets',
'BMUBelow $55M':'Emerging Markets',
'BRA> $100M':'Emerging Markets',
'BRA> $55M':'Emerging Markets',
'BRABelow $55M':'Emerging Markets',
'VGB> $100M':'Emerging Markets',
'VGB> $55M':'Emerging Markets',
'VGBBelow $55M':'Emerging Markets',
'CAN> $100M':'North America Large Firm',
'CAN> $55M':'Canada',
'CANBelow $55M':'Canada',
'CHL> $100M':'Emerging Markets',
'CHL> $55M':'Emerging Markets',
'CHLBelow $55M':'Emerging Markets',
'CHN> $100M':'Emerging Markets', 
'CHN> $55M':'Emerging Markets',
'CHNBelow $55M':'Emerging Markets',
'COL> $100M':'Emerging Markets',
'COL> $55M':'Emerging Markets',
'COLBelow $55M':'Emerging Markets',
'CRI> $100M':'Emerging Markets',
'CRI> $55M':'Emerging Markets',
'CRIBelow $55M':'Emerging Markets',
'DNK> $100M':'Europe Large Firm',
'DNK> $55M':'Europe Large Firm',
'DNKBelow $55M':'Europe Large Firm',
'FIN> $100M':'Europe Large Firm',
'FIN> $55M':'Europe Large Firm',
'FINBelow $55M':'Europe Large Firm',
'FRA> $100M':'Europe Large Firm',
'FRA> $55M':'Europe Large Firm',
'FRABelow $55M':'Europe Large Firm',
'DEU> $100M':'Europe Large Firm',
'DEU> $55M':'Europe Large Firm',
'DEUBelow $55M':'Europe Large Firm',
'GRC> $100M':'Europe Large Firm',
'GRC> $55M':'Europe Large Firm',
'GRC> $55M':'Europe Large Firm',
'GTM> $100M':'Emerging Markets',
'GTM> $55M':'Emerging Markets',
'GTMBelow $55M':'Emerging Markets',
'HND> $100M':'Emerging Markets',
'HND> $55M':'Emerging Markets',
'HNDBelow $55M':'Emerging Markets',
'HKG> $100M':'Emerging Markets',
'HKG> $55M':'Emerging Markets',
'HKGBelow $55M':'Emerging Markets',
'IRL> $100M':'Europe Large Firm',
'IRL> $55M':'Europe Large Firm',
'IRLBelow $55M':'Europe Large Firm',
'ISR> $100M':'Emerging Markets',
'ISR> $55M':'Emerging Markets',
'ISRBelow $55M':'Emerging Markets',
'ITA> $100M':'Europe Large Firm',
'ITA> $55M':'Europe Large Firm',
'ITABelow $55M':'Europe Large Firm',
'JPN> $100M':'Emerging Markets',
'JPN> $55M':'Emerging Markets',
'JPNBelow $55M':'Emerging Markets',
'KOR> $100M':'Emerging Markets',
'KOR> $55M':'Emerging Markets',
'KORBelow $55M':'Emerging Markets',
'KOR> $100M':'Emerging Markets',
'KOR> $55M':'Emerging Markets',
'KORBelow $55M':'Emerging Markets',
'LUX> $100M':'Europe Large Firm',
'LUX> $55M':'Europe Large Firm',
'LUXBelow $55M':'Europe Large Firm',
'MDG> $100M':'Emerging Markets',
'MDG> $55M':'Emerging Markets',
'MDGBelow $55M':'Emerging Markets',
'MEX> $100M':'North America Large Firm',
'MEX> $55M':'Mexico',
'MEXBelow $55M':'Mexico',
'NLD> $100M':'Europe Large Firm',
'NLD> $55M':'Europe Large Firm',
'NLDBelow $55M':'Europe Large Firm',
'NZL> $100M':'Australia',
'NZL> $55M':'Australia',
'NZLBelow $55M':'Australia',
'NOR> $100M':'Europe Large Firm',
'NOR> $55M':'Europe Large Firm',
'NORBelow $55M':'Europe Large Firm',
'PAN> $100M':'Emerging Markets',
'PAN> $55M':'Emerging Markets',
'PANBelow $55M':'Emerging Markets',
'PNG> $100M':'Emerging Markets',
'PNG> $55M':'Emerging Markets',
'PNGBelow $55M':'Emerging Markets',
'PER> $100M':'Emerging Markets',
'PER> $55M':'Emerging Markets',
'PERBelow $55M':'Emerging Markets',
'POL> $100M':'Europe Large Firm',
'POL> $55M':'Europe Large Firm',
'POLBelow $55M':'Europe Large Firm',
'PRT> $100M':'Europe Large Firm',
'PRT> $55M':'Europe Large Firm',
'PRTBelow $55M':'Europe Large Firm',
'RUS> $100M':' ',
'RUS> $55M':' ',
'RUSBelow $55M':' ',
'SGP> $100M':'Emerging Markets',
'SGP> $55M':'Emerging Markets',
'SGPBelow $55M':'Emerging Markets',
'SVN> $100M':'Emerging Markets',
'SVN> $55M':'Emerging Markets',
'SVNBelow $55M':'Emerging Markets',
'ZAF> $100M':'Emerging Markets',
'ZAF> $55M':'Emerging Markets',
'ZAFBelow $55M':'Emerging Markets',
'KRW> $100M':'Emerging Markets',
'KRW> $55M':'Emerging Markets',
'KRWBelow $55M':'Emerging Markets',
'ESP> $100M':'Europe Large Firm',
'ESP> $55M':'Europe Large Firm',
'ESPBelow $55M':'Europe Large Firm',
'SWE> $100M':'Europe Large Firm',
'SWE> $55M':'Europe Large Firm',
'SWEBelow $55M':'Europe Large Firm',
'CHE> $100M':'Europe Large Firm',
'CHE> $55M':'Europe Large Firm',
'CHEBelow $55M': 'Europe Large Firm',
'TWN> $100M':'Emerging Markets',
'TWN> $55M':'Emerging Markets',
'TWNBelow $55M':'Emerging Markets',
'TUR> $100M':'Europe Large Firm',
'TUR> $55M':'Europe Large Firm',
'TURBelow $55M':'Europe Large Firm',
'ARE> $100M':'Emerging Markets',
'ARE> $55M':'Emerging Markets',
'AREBelow $55M':'Emerging Markets',
'GBR> $100M':'Europe Large Firm',
'GBR> $55M':'Europe Large Firm',
'GBRBelow $55M':'Europe Large Firm',
'USA> $100M':'North America Large Firm',
'USA> $55M':'United States',
'USABelow $55M':'United States',
'URY> $100M':'Emerging Markets',
'URY> $55M':'Emerging Markets',
'URYBelow $55M':'Emerging Markets',
'QAR> $100M':'Emerging Markets',
'QAR> $55M':'Emerging Markets',
'QARBelow $55M':'Emerging Markets',
'SAU> $100M':'Emerging Markets',
'SAU> $55M':'Emerging Markets',
'SAUBelow $55M':'Emerging Markets',
'DOM> $100M':'Emerging Markets',
'DOM> $55M':'Emerging Markets',
'DOMBelow $55M':'Emerging Markets',
'IMN> $100M':'Europe Large Firm',
'IMN> $55M':'Europe Large Firm',
'IMNBelow $55M':'Europe Large Firm',
'ECU> $100M':'Emerging Markets',
'ECU> $55M':'Emerging Markets',
'ECUBelow $55M':'Emerging Markets',
'MYS> $100M':'Emerging Markets',
'MYS> $55M':'Emerging Markets',
'MYSBelow $55M':'Emerging Markets',
'CYM> $100M':'Emerging Markets',
'CYM> $55M':'Emerging Markets',
'CYMBelow $55M':'Emerging Markets',
'USA> $100M':'North America Large Firm',
'USA> $55M':'United States',
'USABelow $55M':'United States'})
# Out:
# <ipython-input-44-17549466f9e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['Risk Calc Model 2.0']=result_df['Country + Asset Category'].map({'ARG> $100M':'Emerging Markets',

# %%
result_df['Country'].unique()
# Out:
# array(['United States', nan, 'Canada', 'Brazil', 'Mexico',
#        'United Kingdom', 'Germany', 'Spain', 'Colombia', 'China', 'Peru',
#        'Chile', 'Australia', 'Italy', 'Singapore'], dtype=object)

# %%
risk_calc=pd.read_csv(project_root+'/riskcalc2_0.csv')

result_df_=result_df.merge(risk_calc, left_on=['Country','Asset Category'], right_on=['WorkBench Country', 'Asset Category'], how='left')
result_df_.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29694 entries, 0 to 29693
# Data columns (total 296 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              29632 non-null  float64
#  1   Account Name_x                                                          29632 non-null  object
#  2   Principal ID                                                            29694 non-null  int64
#  3   Principal Name_x                                                        29694 non-null  object
#  4   Principal that Represents the Account                                   29632 non-null  float64
#  5   Account Office                                                          29632 non-null  object
# ...

# %%
#result_df_=result_df_.drop_duplicates(subset=['Combinedfilter'], keep='first')

# %%
result_df_['Model+Sector']=result_df_['RiskCalc Model']+result_df_['Analyzed Sector']
## ERM Custom Fields
#map in the secondary table that references key lookup dimensions for identifying the proper scoring model
#df_=df18.copy()
#mappingtable2=pd.read_csv(mapping_root+'/mappingtable2.csv')
#result_df['Principal ID + Year']=(result_df["Principal ID"].str.cat(result_df[["Statement Date - Year", "Pilot?"]].astype(str), sep=" "))
#result_df['Principal ID + Previous Year']=result_df['Principal ID'].str.cat(result_df[['Prior Year', "Pilot?"]].astype(str), sep= " ")
result_df_["Assets in $ USD"]=(result_df['Assets']*result_df_["FX Rate (As of Dec 2019)"])
#Principal ID + Previous Year + As Stated or As Adjusted #need to 
#df18.reset_index()
result_df_['Principal ID + Year']=result_df_['Principal ID'].astype(str)+ result_df_['Prior Year'].astype(str)+result_df_['Pilot?']
result_df_['Principal ID + Previous Year']=result_df_['Principal ID'].astype(str)+result_df_['Statement Date - Year'].astype(str)+result_df_['Pilot?']

#max total asset value in USD
result_df_['Max Total Asset Value in USD']=result_df_.groupby('Principal ID')['Assets in $ USD'].transform('max')



#Max Statement Year
result_df_['Max FYE']=result_df_.groupby('Principal ID')['Statement Date - Year'].transform('max')

#Analyzed Currency
#mappingtableb=pd.read_csv(project_root+'/mappingtableb.csv')
#df6=df.merge(mappingtable2, on='Currency', how= 'left')
result_df_['Analyzed Currency']=result_df_['ISO Currency Code']


#df19.drop_duplicates(subset = ['Principal ID', 'Account ID'], inplace=True)
#df_a=result_df.copy()
#df__=df_a.merge(mappingtable2, left_on=['Analyzed Country','Asset Category','Country & Asset Category'],right_on=['ISO Country', 'Asset Category','Country & Asset Category'], how='left')
#df['Model']=df__['Risk Calc Model 2.0']

result_df_["User-Defined Time Period (optional)"]=1
result_df_['ERM ID']=''
result_df_['ERM Sector']=''
result_df_['Analyzed Sector']=""

# %%
result_df_.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33091 entries, 0 to 33090
# Data columns (total 298 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              33025 non-null  float64
#  1   Account Name_x                                                          33025 non-null  object
#  2   Principal ID                                                            33091 non-null  int64
#  3   Principal Name_x                                                        33091 non-null  object
#  4   Principal that Represents the Account                                   33025 non-null  float64
#  5   Account Office                                                          33025 non-null  object
# ...

# %%
result_df_.tail()
# Out:
#        Account ID                                     Account Name_x  \
# 33086    300031.0  STORK TECHNICAL SERVICES HOLDING B.V. SUCURSAL...
# 33087    300031.0  STORK TECHNICAL SERVICES HOLDING B.V. SUCURSAL...
# 33088    300277.0                                      INTERNEXA S.A
# 33089    301147.0                                    ACF Minera S.A.
# 33090    301147.0                                    ACF Minera S.A.
#
#        Principal ID                                   Principal Name_x  \
# 33086    1000077914  STORK TECHNICAL SERVICES HOLDING B.V. SUCURSAL...
# 33087    1000077914  STORK TECHNICAL SERVICES HOLDING B.V. SUCURSAL...
# 33088    1000081211                                      INTERNEXA S.A
# 33089    1000086971                                    ACF Minera S.A.
# 33090    1000086971                                    ACF Minera S.A.
#
#        Principal that Represents the Account Account Office   Datadate  \
# ...

# %%
result_df_['Risk Calc Model']=result_df_['RiskCalc Model']

# %% [markdown]
# ## Below's dataframe we can copy and paste right into the Common Data elements and the ERM Group Custom Fields

# %%
ConsolidatedFAW=pd.DataFrame(result_df_[['Account ID', 'Account Name_x', 'Principal Name_x', 
                                        'Principal that Represents the Account', 'Account Office', 'Datadate', 'Country',
                                       'Currency','Units', 'Statement Period','Statement Type', 'Template Type', 'FAW ID',
                                       'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year', 'Current Date - Month',
                                      'Industry Classification', 'Industry Definition', "User-Defined Time Period (optional)", 'Financial Statement Only EDF',
                                       'Principal ID + Year', 'Principal ID + Previous Year', 'Assets in $ USD', 'Max Total Asset Value in USD',
                                       'Analyzed Currency', 'Analyzed Country', 'Asset Category', 'Country + Asset Category', 'Risk Calc Model',
                                       'ERM ID', 'ERM Sector', 'Model+Sector', 'Analyzed Sector', 'Pilot?']])
consolidatedFAW=ConsolidatedFAW.sort_values(by='Statement Type')

# %% [markdown]
# ## Split the data by Core Contract, Commercial, National/International, and output for the consolidated FAW tab

# %%
corecontract_=result_df_[['Principal ID','Assets', 'Current Assets', 'Cash', 'CDs and Marketable Securities', 'Accounts Receivable - Trade',
                               'Accounts Receivable - Other', 'Accounts and Notes Receivable - Related Parties', "Accounts and Notes Receivable - Stockholders'",
                               'Accounts and Notes Receivable - Officers and Employees', 'Retainage', 'Cost and Estimated Earnings in Excess of Billings',
                               'Inventory', 'Accounts Receivable - Trade', 'Accounts Receivable - Over 90 Days', 'Retainage', 'Accounts Receivable - Other',
                               'Accounts and Notes Receivable - Related Parties', "Accounts and Notes Receivable - Stockholders'", 'Accounts and Notes Receivable - Officers and Employees',
                               'Goodwill', 'Other Intangible Assets', 'Equipment', 'Buildings', 'Other Fixed Assets', 'Real Estate', 'Liabilities',
                               'Current Liabilities', 'Working Capital Line', 'Revolving Line of Credit', 'Bank Overdraft', 'Notes Payable - Other', 'Current Portion - Equipment Debt',
                               'Accounts Payable - Trade', 'Retainage', 'Billings in Excess of Cost and Earned Profit', 'Accounts Payable - Related Parties',
                               "Loans and Payables - Stockholders'", "Accounts Payable - Other", 'Long Term Liabilities', 'Revolving Line of Credit',
                               "Accounts and Notes Payable - Stockholders'", 'Notes Payable - Other', 'Real Estate Debt', 'Other Interest Bearing Debt',
                               "Other Long-Term Debt (Non-Interest Bearing)", "Shareholders' Equity", 'Retained Earnings','Revenues', 'Cost of Revenues',
                               'Gross Profit', 'Operating Income', 'Interest Income', 'Interest Expense', 'Net Income Before Taxes', 'Net Income After Taxes',
                               'Net Income After Taxes, Distributions, and Dividends', 'Cash flow from Operations', 'Depreciation and Amortization', 'Max Backlog',
                               'WC % Case', 'NW % Case', 'Interest Coverage', 'Current Ratio', 'Quick Ratio', 'True Cash', "Underbillings to Shareholders' Equity (%)" ,
                               "Underbillings to Working Capital (%)", "Liquidity to Overbillings (%)", 'Accounts Receivable - Turnover', "Gross Profit (%)",
                               "G&A / Revenues (%)", "Net Profit (%)", "ROE", "Debt/Worth", "Overhead to Shareholders' Equity (%)", "Interest Bearing Debt to Stockholders' Equity",
                               "Operating Profit (%)", "G&A Expenses", "Dividends and Distributions", "Dividends", "Subchapter - S Distributions", 'Investments', 'Financing', 'Template Type', 'Combinedfilter']]
corecontract=corecontract_[(corecontract_['Template Type']=='Contract')]

# %%
corecontract.head()
# Out:
#        Principal ID      Assets  Current Assets        Cash  \
# 14046     875398521  30085300.0      29054900.0  15519800.0
# 14047     245395321  89236451.0      39538726.0    751671.0
# 14048     875398521  31402564.0      30005513.0  11553625.0
# 14049     875398521  94987048.0      88710040.0  43983801.0
# 14050     216437712   3285964.0       2974418.0       174.0
#
#        CDs and Marketable Securities  Accounts Receivable - Trade  \
# 14046                            NaN                          NaN
# 14047                            NaN                   23723005.0
# 14048                            NaN                    6202656.0
# 14049                            NaN                    7027449.0
# 14050                            NaN                    2216191.0
#
#        Accounts Receivable - Other  \
# 14046                      45700.0
# 14047                    2718463.0
# 14048                          NaN
# 14049                    2557221.0
# ...

# %%
corecommercial_=result_df_[["Principal ID", 'Account ID','Statement Type',"Assets","Current Assets","Cash","Accounts Receivable",
"Inventory","Goodwill", "Fixed Assets", "Liabilities", "Current Liabilities", 
"Accounts Payable","Long Term Liabilities","Long Term Debt and Notes Payable", "Other Provisions"
,"Shareholders' Equity", "Retained Earnings", "Sales","Cost of Sales","Gross Profit Margin","Earnings Before Interest, Taxes, Depreciation and Amortization",
"Earnings Before Interest and Taxes (EBIT)","Interest Income","Interest Expense (-)","Net Income (Loss)",
"Depreciation and Amortization","Intangibles","Marketable Securities","Long Term Debt Due Within One Year","Other Short Term Interest Bearing Debt",
"Cash Flow from Operating Activities","Net Income (Loss)1", "Capital Expenditures", "Free Cash Flow", "Fixed Charge Coverage", "Interest Bearing Debt"
,"EBITDA", "Return on Capital (%)","Return on Equity (%)","Interest Bearing Debt to Shareholders' Equity","Return on Assets (%)", "Gross Profit (Loss) to Sales (%)"
,"G&A Expense to Sales (%)","Net Profit (Loss) to Sales (%)" , "EBITDA to Sales", "Interest Bearing Debt to EBITDA" ,"EBITDA to Interest Expense",
"Interest Bearing Debt to Operating Cash Flow","Cash Flow to Interest Expense","Free Cash Flow to Interest Expense","Selling, General and Administrative Expenses",
"Depreciation and Amortization", "Other Income (Expense) and Interest", "Cash Flow from Investing Activities", "Cash Flow from Financing Activities"
,"Proceeds from Issuance of Debt","Issuance of Common Shares", "Purchase of Convertible Preferred Securities", "Purchase of Common Shares", "Payments on Debt"
,"Payments on Capital Lease Obligations", "Dividend Payments", 'Template Type', "Account ID"]]
corecommercial=corecommercial_[(corecommercial_['Template Type']=='Commercial')]

# %%
core_commercial.head()
# Out:
#        Principal ID       Assets  Current Assets        Cash  \
# 12692    1000000452  207464000.0     115253000.0   5135000.0
# 12409    1000000452  272424000.0     165714000.0  65911000.0
# 15327    1000000452  396428000.0     175806000.0   1162000.0
# 15329    1000001325  966858000.0     931392000.0  48843000.0
# 15331    1000001325  991761000.0     900320000.0  86419000.0
#
#        Accounts Receivable   Inventory    Goodwill  Fixed Assets  Liabilities  \
# 12692           91221000.0   4890000.0   9846000.0    68026000.0  248938000.0
# 12409           80521000.0   4939000.0   8369000.0    52308000.0  286849000.0
# 15327          131441000.0  11477000.0  28506000.0   112705000.0  469816000.0
# 15329          809967000.0         NaN         NaN    13510000.0  747956000.0
# 15331          776137000.0         NaN  11925000.0    16886000.0  830028000.0
#
#        Current Liabilities  Accounts Payable  Long Term Liabilities  \
# ...

# %%
national_international_=result_df_[['Principal ID', 'Account ID','Statement Type',"Assets","Current Assets","Cash","Marketable Securities","Trade Accounts Receivable", "Other Accounts Receivable",
                                          "Stock (Inventory)", "Work In Progress (WIP)", "Advances","Property","Plant/Equipment","Long Term Receivables",
                                          "Long Term WIP", "Goodwill", "Intangibles","Liabilities", "Current Liabilities","Current Bank Debt - Unsecured",
                                          "Current Bank Debt - Secured","Current Portion of Long Term Debt - Unsecured", "Current Portion of Long Term Debt - Secured",
                                          "Current Portion of Non-Recourse Debt","Trade Accounts Payable","Other Accounts Payable","Advances from Customers","Long Term Liabilities",
                                          "Loans 1-5 Years - Unsecured", "Loans 1-5 Years - Secured", "Loans Over 5 Years - Unsecured", "Loans Over 5 Years - Secured", "Non-Recourse Debt 1-5 Years",
                                          "Non-Recourse Debt - Over 5 Years","Long Term Accounts Payable", "Advances from Customers","Provisions, Other","Stockholders' Equity",
                                          "Retained Earnings","Revenue (Turnover)","Cost of Revenues","Gross Profit","Earnings Before Interest and Taxes (EBIT)","Gross Interest Expense",
                                          "Interest Income", "Other Comprehensive Income/(Expense)", "Total Comprehensive Income (Loss), Less Dividends", "Cash Flow from Operating Activities",
                                          "Net Profit (Loss) Before Dividend", "Depreciation, Amortization and Impairment", "Cash, Outflows for Additions to Property, Plant, and Equipment (CAPEX)",
                                          "EBITDA (EBIT+ Depreciation, Amortization and Impairment)","ROCE (Return on Capital Employed) (%)","Return on Equity (%)","Return on Assets (%)","Operating Margin (%)",
                                          "Profit Before Tax and Minority Interest as % of Turnover (%)","Gross Profit Margin (%)","G&A Expense to Revenues (%)", "Net Interest Bearing Debt to EBITDA",
                                          "Interest Bearing Debt to EBITDA", "Interest Bearing Debt to Stockholders' Equity","Net Interest Bearing Debt to Stockholders' Equity", "Adjusted Interest Bearing Debt to Stockholders' Equity",
                                          "EBIT Interest Coverage", "EBIT Interest Coverage (Net)", "EBITDA to Interest Expense (Net)", "Total Liabilities to Stockholders' Equity", "Gearing (Net Interest Bearing Debt to Stockholders' Equity) (%)",
                                          "Adjusted Gearing (%)", "Cash to Current Liabilities (%)", "Current Ratio","Quick Ratio", "Asset Turnover", "Debtors/Creditors","Accounts Receivables/Revenue",
                                          "Interest Bearing Debt to Operating Cash Flow","Interest Bearing Debt to Free Cash Flow", "Adjusted Debt to Operating Cash Flow", "Adjusted Debt to Free Cash Flow",
                                          "Operating Cash Flow/Profit Before Taxes & Minority Interest", "Debt Service", "Recourse Debt Secured as % of Stockholders' Equity (%)", "Market Capitalization to Stockholders' Equity (%)",
                                          "Dividend as % Profit Before Taxes & Minority Interest (%)","Net Profit (Loss) Before Dividends","Net Profit (Loss) Less Dividends","Selling, General and Administrative Expenses",
                                          "Research and Development Expense", "Other Operating Income/(Expense), Net", "Net Income (Loss) from Continuing Operations", "Other Non-Operating Income/(Expense), Net",
                                          "Profit Before Tax and Minority Interest", "Income Tax Provision (Benefit)" ,"Net Income (Loss) Before Minority Interest", "Minority Interests", "Dividends",
                                          "Decrease (Increase) in Working Capital", "Other Movements","Cash Flow from Investing Activities", "Cash, Inflow from Sale of Property, Plant, and Equipment",
                                          "Cash Outflows for Acquisitions/Investments", "Cash Inflows for Sale/Disposal of Investments", "Other Cash Flow Changes in Investments",
                                          "Cash Flow from Financing Activities", "Dividends - FinancingActivities","Capital Contribution", "Purchase of Treasury and Shares and Options", "Sale of Treasury Shares and Options",
                                          "Movements with Minority Interests","Issuances of Debt", "Repayment of Debt","Other Cash Flow Changes due to Financing Activities", "Change in Cash due to Changes in Scope of Consolidation",
                                          "Changes in Cash due to Changes in Exchange of Rate", "Increase (Decrease) in Cash and Cash Equivalent", "Cash and Cash Equivalents at Beginning of Year", "Effects of Exchange Rate Changes on Opening Balance",
                                          "Cash and Cash Equivalents Retranslated at Beginning of Year", "Cash and Cash Equivalents at End of Year", "Free Cash Flow (Cash Flow from Operations - CAPEX - Dividends)", "Template Type",
                                           "Capital Lease Obligations - Short Term", "Operating Lease Obligations - Short Term", "Current Portion - Other", "Capital Lease Obligations - Long Term", "Operating Lease Obligations - Long Term"]]

NationalInternational=national_international_[(national_international_['Template Type']=='National/International')]

# %%
NetPGE=pd.read_excel(project_root+'/Net PGE.xlsx')
National_International=NationalInternational.merge(NetPGE, on='Principal ID',how='left')

# %%
with pd.ExcelWriter('consolidated FAW 10_10.xlsx') as writer:
    consolidatedFAW.to_excel(writer, sheet_name='Consolidated FAW')
    corecontract.to_excel(writer, sheet_name='core contract')
    corecommercial.to_excel(writer, sheet_name='core commercial')
    NationalInternational.to_excel(writer, sheet_name='National International')

# %%
#df__=df__.dropna(how='all', axis=1)
#df__=df__.drop_duplicates(subset=['Account ID', 'Principal ID', 'FAW ID'])
result_df_.info(verbose=True, null_counts=True)
df__=result_df_.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33091 entries, 0 to 33090
# Data columns (total 299 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              33025 non-null  float64
#  1   Account Name_x                                                          33025 non-null  object
#  2   Principal ID                                                            33091 non-null  int64
#  3   Principal Name_x                                                        33091 non-null  object
#  4   Principal that Represents the Account                                   33025 non-null  float64
#  5   Account Office                                                          33025 non-null  object
# ...

# %%
#Unique value-this combines the Principal ID, Datadate, Template Type/Surety Type, Statement Type-Adjusted or Stated and FAW
df50=pd.DataFrame()
df__["Combined"] = df__["Pilot?"].str.cat(df__[["Principal ID", "Datadate", 'Template Type', 'Statement Type', 'FAW ID']].astype(str), sep="_")
#df['Combined']=df50['Combined']
#combined1=pd.Series(df["Combined"])
#combined1.nunique()

# %% [markdown]
# ## Calculate New Fields Based-Blend 3 Product Types together

# %%
#First we must create a set of data that is sorteed by the Template Type
#create mapping into the cop that is indexed by Risk Calc 2.0
df__['Obligor Name']=result_df['Pilot?']
df__['Obligor Key']=result_df['Principal ID']

#inventory
df__['Inventory']=result_df['Inventory']+result_df['Stock (Inventory)']

# %%
df__.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33091 entries, 0 to 33090
# Data columns (total 300 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              33025 non-null  float64
#  1   Account Name_x                                                          33025 non-null  object
#  2   Principal ID                                                            33091 non-null  int64
#  3   Principal Name_x                                                        33091 non-null  object
#  4   Principal that Represents the Account                                   33025 non-null  float64
#  5   Account Office                                                          33025 non-null  object
# ...

# %%
df__['CashandSecurities']=df__['Cash']+df__['CDs and Marketable Securities']
df__['Total Assets']=df__['Assets']

#current liabilities merged correctly

conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(result_df['Inventory']),(result_df ['Stock (Inventory)']), (result_df['Inventory'])]
df__['Inventory']=np.select(conditions, values)

#longtermdebt

#DeleteLine
df__['CurrentDate_']=df__['Current Date'].apply(pd.to_datetime)
df__['Max FYE Date_']=df__['Max FYE Date'].apply(pd.to_datetime)
df__['Date Difference']=(df__['CurrentDate_']-df__['Max FYE Date_'])/np.timedelta64(1,'D')

#delete line
conditions=[
    (df__['Date Difference']>730),
    (df__['Date Difference']<=730),
    ((df__['Max FYE Date'])==(df__['Datadate']))]
values=['Yes', 'No', 'No']
df__['Delete Line?']=np.select(conditions,values)


#long term debt
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Revolving Line of Credit']+df__['Equipment Debt']+df__['Notes Payable - Other']
+df__['Real Estate Debt']+df__['Other Interest Bearing Debt']+df__["Other Long-Term Debt (Non-Interest Bearing)"]),(df__['Long Term Debt and Notes Payable']), (df__['Loans 1-5 Years - Unsecured']+df__['Loans 1-5 Years - Secured']
+df__['Loans Over 5 Years - Unsecured']+df__['Loans Over 5 Years - Secured']+df__['Non-Recourse Debt 1-5 Years']
+df__['Non-Recourse Debt - Over 5 Years']
)]
df__['LongTermDebt']=np.select(conditions, values)


#Total Liabilities merged correctly
#Retained Earnings Merged Correctly

#sales
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(result_df['Revenues']),(df__['Sales']), (df__["Revenue (Turnover)"])]
df__['Sales']=np.select(conditions, values)


#ebita
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Net Income Before Taxes']+df__['Interest Expense (-)']+df__['Depreciation and Amortization']),(df__['Issuance of Common Shares']), (df__["EBITDA (EBIT+ Depreciation, Amortization and Impairment)"])]
df__['EDITDA']=np.select(conditions, values)
df

#total interest
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Interest Expense (-)']),(df__["Interest Expense (-)"]), (df__['Gross Interest Expense'])]
df__['Total Interest']=np.select(conditions, values)

#net income
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Revenues']),(df__['Depreciation and Amortization']), (df__['Net Profit (Loss) Before Dividends'])]
x = np.arange(len(df))
df__['Net Income']=np.select(conditions, values)

# %%
#net sales
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Net Income After Taxes']),(df__['Sales']), (df__["Revenue (Turnover)"])]
df__['Net Sales']=np.select(conditions, values)

#gross profit
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Gross Profit']),(df__['Gross Profit Margin']), (df__['Gross Profit'])]
df__['Gross Profit']=np.select(conditions, values)

#amortization and depreciation
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Depreciation and Amortization']),(df__['Depreciation and Amortization']), (df__['Depreciation, Amortization and Impairment'])]
df__['Amortization & Depreciation']=np.select(conditions, values)

df__['Industry Classification']="Sector"

df__['User-Defined Time Period']=1

#tangible fixed assets
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Equipment']+df__['Buildings']+df__["Other Fixed Assets"]+df__['Real Estate']+df__['Liabilities']),(df__['Fixed Assets']), (df__['Property']+df__["Plant/Equipment"])]
df__['Tangible Fixed Assets']=np.select(conditions, values)

#intangible fixed assets
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Goodwill']+df__['Other Intangible Assets']),(df__['Goodwill']+df__['Fixed Assets']), (df__['Goodwill']+ df__['Intangibles'])]
df__['Intangible Fixed Assets']=np.select(conditions, values)

#accounts receivable
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Accounts Receivable - Trade']+df__['Accounts Receivable - Other']+df__['Accounts and Notes Receivable - Related Parties']
+df__['Accounts and Notes Receivable - Officers and Employees']+df__["Accounts and Notes Receivable - Stockholders'.1"]), (df__['Accounts Receivable']), (df__['Trade Accounts Receivable']+df__['Other Accounts Receivable'])]
df__['Accounts Receivable']=np.select(conditions, values)

#accounts payable
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Accounts Payable - Trade']+df__['Accounts Payable - Related Parties']+ df__['Accounts Payable - Other']), (df__['Accounts Payable']), (df__['Trade Accounts Payable']+df__['Other Accounts Payable'])]
df__['Accounts Payable']=np.select(conditions, values)

#operating profit
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Operating Income']),(df__["Earnings Before Interest and Taxes (EBIT)"]),(df__['Earnings Before Interest and Taxes (EBIT)']+df__['Depreciation and Amortization'])]
df__['Operating Profit']=np.select(conditions, values)      

#Tangible Fixed Assets
conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Equipment']+df__['Buildings']+df__['Other Fixed Assets']+df__['Real Estate']),(df__["Goodwill"]),(df__['Goodwill']+df__['Intangibles'])]
df__['Tangible Fixed Assets']=np.select(conditions, values)

# %%
#short term debt

conditions=[
    (result_df['Template Type']=='Contract'),
    (result_df['Template Type']=='Core Commercial'),
    (result_df['Template Type']=='National International')]
values=[(df__['Working Capital Line']+df__['Revolving Line of Credit']+df__['Notes Payable - Other']), 
       (df__["Current Bank Debt - Unsecured"]),
       (df__['Long Term Debt Due Within One Year']+df__['Other Short Term Interest Bearing Debt'])]
df__['Short Term Debt']=np.select(conditions,values)


df['Region'] = np.where(df['Country'] =="United States", "Nation" , "")

# %%
with pd.ExcelWriter('consolidated FAW 0926_.xlsx') as writer:
    dfdivide.to_excel(writer, sheet_name='Consolidated FAW')

# %%
#Prev Year 
df__['Prev. Yr. Inventory']=df__.groupby('Statement Date - Year')['Inventory'].shift()
df__['Prev. Yr. Total Assets']=df__.groupby('Statement Date - Year')['Assets'].shift()
df__['Prev. Yr. LT Debt']=df__.groupby('Statement Date - Year')['LongTermDebt'].shift()
df__['Total Interest Expense']=df__.groupby('Statement Date - Year')['LongTermDebt'].shift()
df__['Prev. Yr. Sales']=df__.groupby('Statement Date - Year')['Sales'].shift()
df__['Prev. Yr. Cash and Securities']=df__.groupby('Statement Date - Year')['CashandSecurities'].shift()
df__['Prev. Yr. Accounts Receivable']=df__.groupby('Statement Date - Year')['Accounts Receivable'].shift()
df__['Prev. Yr. Total Assets']=df__.groupby('Statement Date - Year')['Total Assets'].shift()
df__['Prev. Yr. Accounts Payable']=df__.groupby('Statement Date - Year')['Accounts Payable'].shift()
df__['Prev. Yr. Net Income']=df__.groupby('Statement Date - Year')['Net Income'].shift()
df__['Prev. Yr. Total Liabilities']=df__.groupby('Statement Date - Year')['Liabilities'].shift()
df__['Prev. Yr. Net Sales']=df__.groupby('Statement Date - Year')['Net Sales'].shift()
df__['Prev. Yr. Current Total Liabilities']=df__.groupby('Statement Date - Year')['Liabilities'].shift()
df__['Prev. Yr. Cash & Securities']=df__.groupby('Statement Date - Year')['CashandSecurities'].shift()
df__['Prev. Yr. Short Term Debt']=df__.groupby('Statement Date - Year')['Short Term Debt'].shift()
df__['Prev. Yr. Total Current Assets']=df__.groupby('Statement Date - Year')['Current Assets'].shift()
df__['Prev. Yr. Long Term Debt']=df__.groupby('Statement Date - Year')['LongTermDebt'].shift()

# %%
df__.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33091 entries, 0 to 33090
# Data columns (total 329 columns):
#  #   Column                                                                  Dtype
# ---  ------                                                                  -----
#  0   Account ID                                                              float64
#  1   Account Name_x                                                          object
#  2   Principal ID                                                            int64
#  3   Principal Name_x                                                        object
#  4   Principal that Represents the Account                                   float64
#  5   Account Office                                                          object
#  6   Datadate                                                                datetime64[ns]
#  7   Country                                                                 object
# ...

# %%
dfdivide=df__.copy()
dfdivide['Assets']=(df__['Assets']/1000)
dfdivide['Current Assets']=(df__['Current Assets']/1000)
dfdivide['Cash']=(df__['Cash']/1000)
dfdivide['Accounts Receivable']=(df__['Accounts Receivable']/1000)
dfdivide['Inventory']=(df__['Inventory']/1000)
dfdivide['Goodwill']=(df__['Goodwill']/1000)
dfdivide['Fixed Assets']=(df__['Fixed Assets']/1000)
dfdivide['Liabilities']=(df__['Liabilities']/1000) 
dfdivide['Current Liabilities']=(df__['Current Liabilities']/1000)
dfdivide['Accounts Payable']=(df__['Accounts Payable']/1000)
dfdivide['Long Term Liabilities']=(df__['Long Term Liabilities']/1000)
dfdivide['Long Term Debt and Notes Payable']=(df__['Long Term Debt and Notes Payable']/1000)
dfdivide['Other Provisions']=(df__['Other Provisions']/1000)
dfdivide["Shareholders' Equity"]=(df__["Shareholders' Equity"]/1000)
dfdivide['Retained Earnings']=(df__['Retained Earnings']/1000)
dfdivide['Sales']=(df__['Sales']/1000)
dfdivide['Cost of Sales']=(df__['Cost of Sales']/1000)
dfdivide['Gross Profit Margin']=(df__['Gross Profit Margin']/1000)
dfdivide['Earnings Before Interest, Taxes, Depreciation and Amortization']=(df__['Earnings Before Interest, Taxes, Depreciation and Amortization']/1000)
dfdivide['Earnings Before Interest and Taxes (EBIT)']=(df__['Earnings Before Interest and Taxes (EBIT)']/1000)
dfdivide['Interest Income']=(df__['Interest Income']/1000)
dfdivide['Net Income (Loss)']=(df__['Net Income (Loss)']/1000)
dfdivide['Depreciation and Amortization - ADJUSTMENTSTORECONCILENETINCOME']=(df__['Depreciation and Amortization - ADJUSTMENTSTORECONCILENETINCOME']/1000)
dfdivide['Intangibles']=(df__['Intangibles']/1000)
dfdivide['Marketable Securities']=(df__['Marketable Securities']/1000)
dfdivide['Long Term Debt Due Within One Year']=(df__['Long Term Debt Due Within One Year']/1000)
dfdivide['Other Short Term Interest Bearing Debt']=(df__['Other Short Term Interest Bearing Debt']/1000)
dfdivide['Cash Flow from Operating Activities']=(df__['Cash Flow from Operating Activities']/1000)
dfdivide['Net Income (Loss)1']=(df__['Net Income (Loss)1']/1000)
dfdivide['Capital Expenditures']=(df__['Capital Expenditures']/1000)
dfdivide['Free Cash Flow']=(df__['Free Cash Flow']/1000)
dfdivide['Fixed Charge Coverage']=(df__['Fixed Charge Coverage']/1000)
dfdivide['Interest Bearing Debt']=(df__['Interest Bearing Debt']/1000)
dfdivide['EBITDA']=(df__['EBITDA']/1000)
dfdivide["Return on Capital (%)"]=(df__["Return on Capital (%)"]/1000)
dfdivide["Return on Equity (%)"]=(df__["Return on Equity (%)"]/1000)
dfdivide["Interest Bearing Debt to Shareholders' Equity"]=(df__["Interest Bearing Debt to Shareholders' Equity"]/1000)
dfdivide["Return on Assets (%)"]=(df__["Return on Assets (%)"]/1000)
dfdivide["Gross Profit (Loss) to Sales (%)"]=(df__["Gross Profit (Loss) to Sales (%)"]/1000)
dfdivide["G&A Expense to Sales (%)"]=(df__["G&A Expense to Sales (%)"]/1000)
dfdivide["Net Profit (Loss) to Sales (%)"]=(df__["Net Profit (Loss) to Sales (%)"]/1000)
dfdivide["EBITDA to Sales"]=(df__["EBITDA to Sales"]/1000)
dfdivide["Interest Bearing Debt to EBITDA"]=(df__["Interest Bearing Debt to EBITDA"]/1000)
dfdivide["EBITDA to Interest Expense"]=(df__["EBITDA to Interest Expense"]/1000)
dfdivide["Interest Bearing Debt to Operating Cash Flow"]=(df__["Interest Bearing Debt to Operating Cash Flow"]/1000)
dfdivide["Cash Flow to Interest Expense"]=(df__["Cash Flow to Interest Expense"]/1000)
dfdivide["Free Cash Flow to Interest Expense"]=(df__["Free Cash Flow to Interest Expense"]/1000)
dfdivide["Selling, General and Administrative Expenses"]=(df__["Selling, General and Administrative Expenses"]/1000)
dfdivide["Depreciation and Amortization"]=(df__["Depreciation and Amortization"]/1000)
dfdivide["Other Income (Expense) and Interest"]=(df__["Other Income (Expense) and Interest"]/1000)
dfdivide['Cash Flow from Investing Activities']=(df__['Cash Flow from Investing Activities']/1000)
dfdivide["Cash Flow from Financing Activities"]=(df__["Cash Flow from Financing Activities"]/1000)
dfdivide["Proceeds from Issuance of Debt"]=(df__["Proceeds from Issuance of Debt"]/1000)
dfdivide['Issuance of Common Shares']=(df__['Issuance of Common Shares']/1000)
dfdivide['Purchase of Convertible Preferred Securities']=(df__["Purchase of Convertible Preferred Securities"]/1000)
dfdivide['Purchase of Common Shares']=(df__['Purchase of Common Shares']/1000)
dfdivide['Payments on Debt']=(df__['Payments on Debt']/1000)
dfdivide['Payments on Capital Lease Obligations']=(df__['Payments on Capital Lease Obligations']/1000)
dfdivide['Dividend Payments']=(df__['Dividend Payments']/1000)
dfdivide['ProbableGrossExposureAmt']=(df__['ProbableGrossExposureAmt']/1000)
dfdivide['CDs and Marketable Securities']=(df__['CDs and Marketable Securities']/1000)
dfdivide['Accounts Receivable - Trade']=(df__['Accounts Receivable - Trade']/1000)
dfdivide['Accounts Receivable - Other']=(df__['Accounts Receivable - Other']/1000)
dfdivide['Accounts and Notes Receivable - Related Parties']=(df__['Accounts and Notes Receivable - Related Parties']/1000)
dfdivide["Accounts and Notes Receivable - Stockholders'"]=(df__["Accounts and Notes Receivable - Stockholders'"]/1000)
dfdivide['Accounts and Notes Receivable - Officers and Employees']=(df__['Accounts and Notes Receivable - Officers and Employees']/1000)
dfdivide['Retainage']=(df__['Retainage']/1000)
dfdivide['Cost and Estimated Earnings in Excess of Billings']=(df__['Cost and Estimated Earnings in Excess of Billings']/1000)
dfdivide['Accounts Receivable - Trade.1']=(df__['Accounts Receivable - Trade.1']/1000)
dfdivide['Accounts Receivable - Over 90 Days']=(df__['Accounts Receivable - Over 90 Days']/1000)
dfdivide['Retainage.1']=(df__['Retainage.1']/1000)
dfdivide['Accounts Receivable - Other.1']=(df__['Accounts Receivable - Other.1']/1000)
dfdivide['Accounts and Notes Receivable - Related Parties.1']=(df__['Accounts and Notes Receivable - Related Parties.1']/1000)
dfdivide["Accounts and Notes Receivable - Stockholders'.1"]=(df__["Accounts and Notes Receivable - Stockholders'.1"]/1000)
dfdivide["Accounts and Notes Receivable - Officers and Employees.1" ]=(df__["Accounts and Notes Receivable - Officers and Employees.1" ]/1000)
dfdivide['Other Intangible Assets']=(df__['Other Intangible Assets']/1000)
dfdivide['Equipment']=(df__['Equipment']/1000)
dfdivide['Buildings']=(df__['Buildings']/1000)
dfdivide['Other Fixed Assets']=(df__['Other Fixed Assets']/1000)
dfdivide['Real Estate']=(df__['Real Estate']/1000)
dfdivide['Working Capital Line']=(df__['Working Capital Line']/1000)
dfdivide['Revolving Line of Credit']=(df__['Revolving Line of Credit']/1000)
dfdivide['Bank Overdraft']=(df__['Bank Overdraft']/1000)
dfdivide['Notes Payable - Other']=(df__['Notes Payable - Other']/1000)
dfdivide['Current Portion - Equipment Debt']=(df__['Current Portion - Equipment Debt']/1000)
dfdivide['Accounts Payable - Trade']=(df__['Accounts Payable - Trade']/1000)
dfdivide['Retainage.2']=(df__['Retainage.2']/1000)
dfdivide['Billings in Excess of Cost and Earned Profit']=(df__['Billings in Excess of Cost and Earned Profit']/1000)
dfdivide['Accounts Payable - Related Parties']=(df__['Accounts Payable - Related Parties']/1000)
dfdivide["Loans and Payables - Stockholders'"]=(df__["Loans and Payables - Stockholders'"]/1000)
dfdivide['Accounts Payable - Other']=(df__['Accounts Payable - Other']/1000)
dfdivide['Revolving Line of Credit.1']=(df__['Revolving Line of Credit.1']/1000)
dfdivide['Accounts and Notes Payable - Related Parties']=(df__['Accounts and Notes Payable - Related Parties']/1000)
dfdivide['Equipment Debt']=(df__['Equipment Debt']/1000)
dfdivide["Accounts and Notes Payable - Stockholders"]=(df__["Accounts and Notes Payable - Stockholders'"]/1000)
dfdivide['Notes Payable - Other.1']=(df__['Notes Payable - Other.1']/1000)
dfdivide['Real Estate Debt']=(df__['Real Estate Debt']/1000)
dfdivide['Other Interest Bearing Debt']=(df__['Other Interest Bearing Debt']/1000)
dfdivide["Other Long-Term Debt (Non-Interest Bearing)"]=(df__["Other Long-Term Debt (Non-Interest Bearing)"]/1000)
dfdivide['Revenues']=(df__['Revenues']/1000)
dfdivide['Cost of Revenues']=(df__['Cost of Revenues']/1000)
dfdivide['Gross Profit']=(df__['Gross Profit']/1000)
dfdivide['Operating Income']=(df__['Operating Income']/1000)
dfdivide['Interest Expense']=(df__['Interest Expense']/1000)
dfdivide['Net Income Before Taxes']=(df__['Net Income Before Taxes']/1000)
dfdivide['Net Income After Taxes']=(df__['Net Income After Taxes']/1000)
dfdivide['Net Income After Taxes, Distributions, and Dividends']=(df__['Net Income After Taxes, Distributions, and Dividends']/1000)
dfdivide['Cash flow from Operations']=(df__['Cash flow from Operations']/1000)
dfdivide['Max Backlog']=(df__['Max Backlog']/1000)
dfdivide['WC % Case']=(df__['WC % Case']/1000)
dfdivide['NW % Case']=(df__['NW % Case']/1000)
dfdivide['Interest Coverage']=(df__['Interest Coverage']/1000)
dfdivide['Current Ratio']=(df__['Current Ratio']/1000)
dfdivide['Quick Ratio']=(df__['Quick Ratio']/1000)
dfdivide['True Cash']=(df__['True Cash']/1000)
dfdivide["Underbillings to Shareholders' Equity (%)"]=(df__["Underbillings to Shareholders' Equity (%)"]/1000)
dfdivide["Underbillings to Working Capital (%)"]=(df__["Underbillings to Working Capital (%)"]/1000)
dfdivide["Liquidity to Working Capital (%)"]=(df__["Liquidity to Working Capital (%)"]/1000)
dfdivide["Liquidity to Overbillings (%)"]=(df__["Liquidity to Overbillings (%)"]/1000)
dfdivide['Accounts Receivable - Turnover']=(df__['Accounts Receivable - Turnover']/1000)
dfdivide['Accounts Payable - Turnover']=(df__['Accounts Payable - Turnover']/1000)
dfdivide["Gross Profit (%)"]=(df__["Gross Profit (%)"]/1000)
dfdivide["G&A / Revenues (%)"]=(df__["G&A / Revenues (%)"]/1000)
dfdivide["Net Profit (%)"]=(df__["Net Profit (%)"]/1000)
dfdivide['ROE']=(df__['ROE']/1000)
dfdivide['Debt/Worth']=(df__['Debt/Worth']/1000)
dfdivide["Overhead to Shareholders' Equity (%)"]=(df__["Overhead to Shareholders' Equity (%)"]/1000)

# %%
dfdivide["Operating Profit (%)"]=(df__["Operating Profit (%)"]/1000)
dfdivide['G&A Expenses']=(df__['G&A Expenses']/1000)
dfdivide['Dividends and Distributions']=(df__['Dividends and Distributions']/1000)
dfdivide['Dividends']=(df__['Dividends']/1000)
dfdivide['Subchapter - S Distributions']=(df__['Subchapter - S Distributions']/1000)
dfdivide['Investments']=(df__['Investments']/1000)
dfdivide['Financing']=(df__['Financing']/1000)
dfdivide['Capital Lease Obligations - Short Term']=(df__['Capital Lease Obligations - Short Term']/1000)
dfdivide['Operating Lease Obligations - Short Term']=(df__['Operating Lease Obligations - Short Term']/1000)
dfdivide['Current Portion - Other']=(df__['Current Portion - Other']/1000)
dfdivide['Capital Lease Obligations - Long Term']=(df__['Capital Lease Obligations - Long Term']/1000)
dfdivide['Operating Lease Obligations - Long Term']=(df__['Operating Lease Obligations - Long Term']/1000)
dfdivide['Trade Accounts Receivable']=(df__['Trade Accounts Receivable']/1000)
dfdivide['Other Accounts Receivable']=(df__['Other Accounts Receivable']/1000)
dfdivide["Stock (Inventory)"]=(df__["Stock (Inventory)"]/1000)
dfdivide["Work In Progress (WIP)"]=(df__["Work In Progress (WIP)"]/1000)
dfdivide['Advances']=(df__['Advances']/1000)
dfdivide['Property']=(df__['Property']/1000)
dfdivide['Plant/Equipment']=(df__['Plant/Equipment']/1000)
dfdivide['Long Term Receivables']=(df__['Long Term Receivables']/1000)
dfdivide['Long Term WIP']=(df__['Long Term WIP']/1000)
dfdivide['Current Bank Debt - Unsecured']=(df__['Current Bank Debt - Unsecured']/1000)
dfdivide['Current Bank Debt - Secured']=(df__['Current Bank Debt - Secured']/1000)
dfdivide['Current Portion of Long Term Debt - Unsecured']=(df__['Current Portion of Long Term Debt - Unsecured']/1000)
dfdivide['Current Portion of Long Term Debt - Secured']=(df__['Current Portion of Long Term Debt - Secured']/1000)
dfdivide['Current Portion of Non-Recourse Debt']=(df__['Current Portion of Non-Recourse Debt']/1000)
dfdivide['Trade Accounts Payable']=(df__['Trade Accounts Payable']/1000)
dfdivide['Other Accounts Payable']=(df__['Other Accounts Payable']/1000)
dfdivide['Advances from Customers']=(df__['Advances from Customers']/1000)
dfdivide['Loans 1-5 Years - Unsecured']=(df__['Loans 1-5 Years - Unsecured']/1000)
dfdivide['Loans 1-5 Years - Secured']=(df__['Loans 1-5 Years - Secured']/1000)
dfdivide['Loans Over 5 Years - Unsecured']=(df__['Loans Over 5 Years - Unsecured']/1000)
dfdivide['Loans Over 5 Years - Secured']=(df__['Loans Over 5 Years - Secured']/1000)
dfdivide['Non-Recourse Debt 1-5 Years']=(df__['Non-Recourse Debt 1-5 Years']/1000)
dfdivide['Non-Recourse Debt - Over 5 Years']=(df__['Non-Recourse Debt - Over 5 Years']/1000)
dfdivide['Long Term Accounts Payable']=(df__['Long Term Accounts Payable']/1000)
dfdivide['Advances from Customers.1']=(df__['Advances from Customers.1']/1000)
dfdivide['Provisions, Other']=(df__['Provisions, Other']/1000)
dfdivide["Stockholders' Equity"]=(df__["Stockholders' Equity"]/1000)
dfdivide["Revenue (Turnover)"]=(df__["Revenue (Turnover)"]/1000)
dfdivide['Prev. Yr. Inventory']=(df__['Prev. Yr. Inventory']/1000)
dfdivide['Prev. Yr. Total Assets']=(df__['Prev. Yr. Total Assets']/1000)
dfdivide['Prev. Yr. Accounts Payable']=(df__['Prev. Yr. Accounts Payable']/1000)
dfdivide['Prev. Yr. LT Debt']=(df__['Prev. Yr. LT Debt']/1000)
dfdivide['Total Liabilities']=(df__['Liabilities']/1000)
dfdivide['Prev. Yr. Sales']=(df__['Prev. Yr. Sales']/1000)
dfdivide['Prev. Yr. Net Income']=(df__['Prev. Yr. Net Income']/1000)

# %%
dfdivide['obligorName']=dfdivide['Obligor Name']
dfdivide['entityIdentifier']=dfdivide['Obligor Key']
dfdivide['financialStatementDate']=dfdivide['Datadate']
dfdivide['cash']=dfdivide['Cash']
dfdivide['totalAssets']=dfdivide['Total Assets']
dfdivide['totalAccountsPayable']=dfdivide['Accounts Payable']
dfdivide['totalCurrentLiabilities']=dfdivide['Current Liabilities']              
dfdivide['totalLiabilitiesPreviousYear']=dfdivide['Prev. Yr. Total Liabilities']
dfdivide['totalSales']=dfdivide['Sales']
dfdivide['totalSalesPreviousYear']=dfdivide['Prev. Yr. Sales']
dfdivide['totalOperatingProfit']=dfdivide['Operating Income']
dfdivide['totalAmortizationAndDepreciation']=dfdivide['Depreciation, Amortization and Impairment']
dfdivide['Interest Expense']=dfdivide['Interest Expense']
dfdivide['primaryIndustryClassification']=dfdivide['Industry Classification']
dfdivide['netIncome']=dfdivide['Net Income']
dfdivide['Industry']=dfdivide['Industry Classification']
dfdivide['primaryIndustry']=dfdivide['Industry']
dfdivide['pdTerm']= dfdivide[ "User-Defined Time Period (optional)"]
dfdivide['Financial Statement Only EDF']='OFF'
dfdivide['isTTC']=dfdivide['Financial Statement Only EDF'] 

dfdivide['Principal ID + Year']=dfdivide['Principal ID']+dfdivide['Statement Date - Year']
dfdivide ['Cash & Marketable Securities']=dfdivide['Cash']+dfdivide['CDs and Marketable Securities']
dfdivide['Cash and Cash Equivalents']=dfdivide['Cash and Cash Equivalents at Beginning of Year']+dfdivide['Increase (Decrease) in Cash and Cash Equivalent']
dfdivide["Exchange Rate"]=" "
dfdivide['Statement Month']=dfdivide['Statement Date - Month'].astype(str)
dfdivide['Statement Year']=dfdivide['Statement Date - Year'].astype(str)
dfdivide['FYE Date'] = dfdivide['Datadate']
dfdivide['Current Month']=dfdivide['Current Date - Month'].astype(str)
dfdivide['Current Year']=dfdivide['Current Date - Year'].astype(str)
dfdivide['Current Date'] = date.strftime('%dd/%mm/%yy')

dfdivide['Finanancial Statement Only EDF']='OFF'
dfdivide['asOfDate']=dfdivide['Current Date']
dfdivide['totalInterestExpense']=dfdivide['Total Interest Expense']
dfdivide['totalLiabilities']=dfdivide['Total Liabilities']
dfdivide['totalAssetsPreviousYear']=dfdivide['Prev. Yr. Total Assets']
dfdivide['Cash & Securities']=dfdivide['CashandSecurities']
dfdivide['Long Term Debt']=dfdivide['LongTermDebt']
dfdivide['Total Inventory']=dfdivide['Inventory']
dfdivide['Total Assets']=dfdivide['Assets']
dfdivide['Cash & Securities']=dfdivide['CashandSecurities']
dfdivide['Statement Mapped Date']=dfdivide['Datadate']
dfdivide['Current Mapped Date']=dfdivide['Current Date']
dfdivide['Short Term Debt']=df__['Short Term Debt']

# %%
dfdivide.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33091 entries, 0 to 33090
# Data columns (total 373 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Account ID                                                              33025 non-null  float64
#  1   Account Name_x                                                          33025 non-null  object
#  2   Principal ID                                                            33091 non-null  int64
#  3   Principal Name_x                                                        33091 non-null  object
#  4   Principal that Represents the Account                                   33025 non-null  float64
#  5   Account Office                                                          33025 non-null  object
# ...

# %%
##ask raj if he wanted a separate tab like he does now with the input file that includes the max statement date/year/delete line 
#and the other values for verification purposes

# %%
Canada11=pd.DataFrame()
    
Canada11=dfdivide[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month','Statement Mapped Date','Max FYE Date','Current Mapped Date', 'Delete Line?', 'Inventory', 'Prev. Yr. Inventory', 'Accounts Receivable', 'Prev. Yr. Accounts Receivable',
                     'Cash & Securities', 'Total Assets', 'Prev. Yr. Total Assets', 'Accounts Payable', 'Prev. Yr. Accounts Payable',
                      'Current Liabilities','Long Term Debt', 'Total Liabilities', 'Retained Earnings', 'Sales', 'Prev. Yr. Sales',
                     "EBITDA", 'Total Interest Expense', 'Net Income','Prev. Yr. Net Income', 'Industry Classification','Industry Definition', 
                  'User-Defined Time Period', 'Financial Statement Only EDF','Statement Date - Year', 'Statement Date - Month', 'Datadate', 'RiskCalc Model']] 


Canada111 = Canada11[(Canada11['RiskCalc Model']=="Canada")]
Canada2=Canada111.copy()
Canada2.reset_index()
Canada2['Current Date - Year']=((pd.datetime.now().year)-1)
Canada3=Canada111.copy()
Canada3.reset_index()
Canada3['Current Date - Year']=((pd.datetime.now().year)-2)
Canada4=Canada111.copy()
Canada4.reset_index()
Canada4['Current Date - Year']=((pd.datetime.now().year)-3)
Canada5=Canada111.copy()
Canada5.reset_index()
Canada5['Current Date - Year']=((pd.datetime.now().year)-4)
Canada6=Canada111.copy()
Canada5.reset_index()
Canada6['Current Date - Year']=((pd.datetime.now().year)-5)
#when replicating the dataset make each copy the year prior
Canada=Canada111.append([Canada2,Canada3, Canada4, Canada5, Canada6], ignore_index=True)

Canadacsv=Canada[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month','Statement Mapped Date','Max FYE Date','Current Mapped Date', 'Delete Line?', 'Inventory', 'Prev. Yr. Inventory', 'Accounts Receivable', 'Prev. Yr. Accounts Receivable',
                     'Cash & Securities', 'Total Assets', 'Prev. Yr. Total Assets', 'Accounts Payable', 'Prev. Yr. Accounts Payable',
                      'Current Liabilities','Long Term Debt', 'Total Liabilities', 'Retained Earnings', 'Sales', 'Prev. Yr. Sales',
                     "EBITDA", 'Total Interest Expense', 'Net Income','Prev. Yr. Net Income', 'Industry Classification','Industry Definition', 
                  'User-Defined Time Period', 'Financial Statement Only EDF']]

Canadainput=Canada[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Inventory', 'Prev. Yr. Inventory', 'Accounts Receivable', 'Prev. Yr. Accounts Receivable',
                     'Cash & Securities', 'Total Assets', 'Prev. Yr. Total Assets', 'Accounts Payable', 'Prev. Yr. Accounts Payable',
                      'Current Liabilities','Long Term Debt', 'Total Liabilities', 'Retained Earnings', 'Sales', 'Prev. Yr. Sales',
                     "EBITDA", 'Total Interest Expense', 'Net Income','Prev. Yr. Net Income', 'Industry Classification','Industry Definition', 
                  'User-Defined Time Period', 'Financial Statement Only EDF']]
#Canadamax=Canada.set_index(['Obligor Name','Obligor Key'])
#Canadamax.sort_values(by=['Statement Date - Year', 'Statement Date - Month'])

# %%
Canadainput.head()
# Out:
#   Obligor Name  Obligor Key  Statement Date - Year  Statement Date - Year  \
# 0       Stated  456383812.0                   2017                   2017
# 1       Stated  124630952.0                   2017                   2017
# 2       Stated  384608952.0                   2018                   2018
# 3       Stated  999878838.0                   2020                   2020
# 4       Stated  999905921.0                   2019                   2019
#
#    Statement Date - Month  Statement Date - Month Current Date - Year  \
# 0                       6                       6                2022
# 1                      12                      12                2022
# 2                      12                      12                2022
# 3                      12                      12                2022
# 4                      12                      12                2022
#
#   Current Date - Month  Inventory  Prev. Yr. Inventory  Accounts Receivable  \
# ...

# %%
with pd.ExcelWriter('Canada0920_.xlsx') as writer:
    Canadacsv.to_excel(writer, sheet_name='Canada CSV')
    Canadainput.to_excel(writer, sheet_name='Canada')

# %%
dfdivide['Operating Profit']=dfdivide["Operating Profit (%)"]
dfdivide['Exchange Rate']=dfdivide["FX Rate (As of Dec 2019)"]
dfdivide['Cash and Securities']=dfdivide['CashandSecurities']

# %%
EmergingMarkets=pd.DataFrame()

EmergingMarkets=dfdivide[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash and Securities','Inventory', 'Current Assets','Total Assets','Current Liabilities','Total Liabilities',
                     'Sales', 'Prev. Yr. Sales',  'Amortization & Depreciation', "Operating Profit",
                         'Interest Expense', 'Net Income', 'Country', 'Industry Classification', 'Industry Definition',
                     'Financial Statement Only EDF','Currency', 'Exchange Rate','Risk Calc Model', 'Max FYE Date', 'Delete Line?', 'Current Mapped Date', 'Statement Mapped Date']]
EmergingMarkets1=EmergingMarkets[(EmergingMarkets['Risk Calc Model']=="Emerging Markets")]


EmergingMarkets2=EmergingMarkets1.copy()
EmergingMarkets2.reset_index()
EmergingMarkets2['Current Date - Year']=((pd.datetime.now().year)-1)
EmergingMarkets3=EmergingMarkets2.copy()
EmergingMarkets3.reset_index()
EmergingMarkets3['Current Date - Year']=((pd.datetime.now().year)-2)
EmergingMarkets4=EmergingMarkets3.copy()
EmergingMarkets4.reset_index()
EmergingMarkets4['Current Date - Year']=((pd.datetime.now().year)-3)
EmergingMarkets5=EmergingMarkets4.copy()
EmergingMarkets5.reset_index()
EmergingMarkets5['Current Date - Year']=((pd.datetime.now().year)-4)
EmergingMarkets6=EmergingMarkets5.copy()
EmergingMarkets6.reset_index()
EmergingMarkets6['Current Date - Year']=((pd.datetime.now().year)-5)
Emerging12=EmergingMarkets1.append(EmergingMarkets2, ignore_index=True)
Emerging123=Emerging12.append(EmergingMarkets3,ignore_index=True)
Emerging1234=Emerging123.append(EmergingMarkets4,ignore_index=True)
Emerging12345=Emerging1234.append(EmergingMarkets5,ignore_index=True)
Emerging=Emerging12345.append(EmergingMarkets6, ignore_index=True)

#Emergingmax=Emerging.set_index(['Obligor Key'])
#Emergingsort=Emerging.sort_values(by=['Statement Date - Year', 'Statement Date - Month'])
EmergingMarkets=Emerging[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Statement Mapped Date', 'Max FYE Date', 'Current Mapped Date', 'Delete Line?','Cash and Securities','Inventory', 'Current Assets','Total Assets','Current Liabilities','Total Liabilities',
                     'Sales', 'Prev. Yr. Sales',  'Amortization & Depreciation', "Operating Profit",
                         'Interest Expense', 'Net Income', 'Country', 'Industry Classification', 'Industry Definition',
                     'Financial Statement Only EDF','Currency', 'Exchange Rate']]

EmerginginputOff=Emerging[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash and Securities','Inventory', 'Current Assets','Total Assets','Current Liabilities','Total Liabilities',
                     'Sales', 'Prev. Yr. Sales',  'Amortization & Depreciation', "Operating Profit",
                         'Interest Expense', 'Net Income', 'Country', 'Industry Classification', 'Industry Definition',
                     'Financial Statement Only EDF','Currency', 'Exchange Rate'  ]]
Emerginginput=EmerginginputOff[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash and Securities','Inventory', 'Current Assets','Total Assets','Current Liabilities','Total Liabilities',
                     'Sales', 'Prev. Yr. Sales',  'Amortization & Depreciation', "Operating Profit",
                         'Interest Expense', 'Net Income', 'Country', 'Industry Classification', 'Industry Definition',
                     'Financial Statement Only EDF','Currency', 'Exchange Rate'  ]]
Emergingon=Emerginginput.copy()
Emergingon['Financial Statement Only EDF']='ON'

# %%
with pd.ExcelWriter('EmergingMarkets.xlsx') as writer:
   # Emergingmax.to_excel(writer, sheet_name='Emerging')
    Emerginginput.to_excel(writer, sheet_name='Emerging Markets')
    Emergingon.to_excel(writer, sheet_name='Emerging Markets ON')
    EmerginginputOff.to_excel(writer, sheet_name='Emerging Markets OFF')

# %%
Emerginginput.head()
# Out:
#   Obligor Name  Obligor Key  Statement Date - Year  Statement Date - Month  \
# 0       Stated  369267032.0                   2018                       3
# 1       Stated  996389412.0                   2019                       3
# 2       Stated  336380912.0                   2018                       9
# 3       Stated  316386612.0                   2015                      12
# 4       Stated  316386612.0                   2016                      12
#
#   Current Date - Year Current Date - Month  Cash and Securities  Inventory  \
# 0                2022                   09                  NaN        0.0
# 1                2022                   09                  NaN        0.0
# 2                2022                   09                  NaN        0.0
# 3                2022                   09                  NaN        0.0
# 4                2022                   09                  NaN        0.0
#
# ...

# %%
dfdivide['Country or Region']=dfdivide['Analyzed Country']
dfdivide['Industry Definition']=dfdivide['Industry']
dfdivide['Amortization and Depreciation']=dfdivide['Amortization & Depreciation']

# %%
EuropeLargeFirm=pd.DataFrame()

EuropeLargeFirm=dfdivide[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash and Cash Equivalents', 'Total Assets', 'Prev. Yr. Total Assets', 'Accounts Payable',
                     'Current Liabilities','Total Liabilities','Sales', 'Prev. Yr. Sales', 'Amortization and Depreciation',
                    'Operating Profit', 'Interest Expense', 'Net Income', 'Prev. Yr. Net Income', 'Country or Region', 
                    'Industry Classification', 'Industry Definition', "User-Defined Time Period (optional)",
                     'Financial Statement Only EDF', 'Risk Calc Model', 'Statement Mapped Date', 'Max FYE Date', 'Current Mapped Date', 'Delete Line?']]
EuropeLargeFirm1=EuropeLargeFirm[(EuropeLargeFirm['Risk Calc Model']=="Europe Large Firm")]

Europe2=EuropeLargeFirm1.copy()
Europe2.reset_index()
Europe2['Current Date - Year']=((pd.datetime.now().year)-1)
Europe3=EuropeLargeFirm1.copy()
Europe2['Current Date - Year']=((pd.datetime.now().year)-2)                         
Europe4=EuropeLargeFirm1.copy()
Europe4['Current Date - Year']=((pd.datetime.now().year)-3) 
Europe5=EuropeLargeFirm1.copy()
Europe5['Current Date - Year']=((pd.datetime.now().year)-4) 
Europe6=EuropeLargeFirm1.copy()
Europe6['Current Date - Year']=((pd.datetime.now().year)-5)
Europe12=EuropeLargeFirm1.append(Europe2, ignore_index=True)
Europe123=Europe12.append(Europe3,ignore_index=True)
Europe1234=Europe123.append(Europe4,ignore_index=True)
Europe=Europe1234.append(Europe5,ignore_index=True)
Europeinput=Europe[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month','Statement Mapped Date', 'Max FYE Date', 'Current Mapped Date', 'Delete Line?', 'Cash and Cash Equivalents', 'Total Assets', 'Prev. Yr. Total Assets', 'Accounts Payable',
                     'Current Liabilities','Total Liabilities','Sales', 'Prev. Yr. Sales', 'Amortization and Depreciation',
                    'Operating Profit', 'Interest Expense', 'Net Income', 'Prev. Yr. Net Income', 'Country or Region', 
                    'Industry Classification', 'Industry Definition', "User-Defined Time Period (optional)",
                     'Financial Statement Only EDF']]
Europecsv=Europe[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash and Cash Equivalents', 'Total Assets', 'Prev. Yr. Total Assets', 'Accounts Payable',
                     'Current Liabilities','Total Liabilities','Sales', 'Prev. Yr. Sales', 'Amortization and Depreciation',
                    'Operating Profit', 'Interest Expense', 'Net Income', 'Prev. Yr. Net Income', 'Country or Region', 
                    'Industry Classification', 'Industry Definition', "User-Defined Time Period (optional)",
                     'Financial Statement Only EDF']]

# %%
with pd.ExcelWriter('EuropeLarge0906.xlsx') as writer:
   # Emergingmax.to_excel(writer, sheet_name='Emerging')
    Europeinput.to_excel(writer, sheet_name='Europe Large Firm')
    Europecsv.to_excel(writer, sheet_name='CSV')

# %%
Mexicos=dfdivide[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash & Marketable Securities', 'Total Inventory', 'Tangible Fixed Assets','Intangible Fixed Assets', 'Total Assets'
                    , 'Total Liabilities', 'Net Sales', "Prev. Yr. Net Sales", 'Gross Profit', "Amortization & Depreciation", "Operating Profit",
                  "Total Interest Expense"  ,"User-Defined Time Period (optional)", 'Financial Statement Only EDF', 'Risk Calc Model', "Max FYE Date", 'Current Mapped Date', 'Statement Mapped Date', 'Delete Line?']]
Mexicos1=Mexicos[(Mexicos['Risk Calc Model']=="Mexico")]

Mexico2=Mexicos1.copy()
Mexico2['Current Date - Year']=((pd.datetime.now().year)-1)
Mexico3=Mexicos1.copy()
Mexico3['Current Date - Year']=((pd.datetime.now().year)-2)
Mexico4=Mexicos1.copy()
Mexico4['Current Date - Year']=((pd.datetime.now().year)-3)
Mexico5=Mexicos1.copy()
Mexico5['Current Date - Year']=((pd.datetime.now().year)-4)
Mexico6=Mexicos1.copy()
Mexico6['Current Date - Year']=((pd.datetime.now().year)-5)
Mexico12=Mexicos1.append(Mexico2, ignore_index=True)
Mexico123=Mexico12.append(Mexico3,ignore_index=True)
Mexico1234=Mexico123.append(Mexico4,ignore_index=True)
Mexico12345=Mexico1234.append(Mexico5, ignore_index=True)
Mexico=Mexico12345.append(Mexico6,ignore_index=True)
Mexicoinput=Mexico[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Statement Mapped Date', 'Max FYE Date', 'Current Mapped Date',  'Delete Line?','Cash & Marketable Securities', 'Total Inventory', 'Tangible Fixed Assets','Intangible Fixed Assets', 'Total Assets'
                    , 'Total Liabilities', 'Net Sales', "Prev. Yr. Net Sales", 'Gross Profit', "Amortization & Depreciation", "Operating Profit",
                  "Total Interest Expense"  ,"User-Defined Time Period (optional)", 'Financial Statement Only EDF']]
MexicosCSV=Mexico[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash & Marketable Securities', 'Total Inventory', 'Tangible Fixed Assets','Intangible Fixed Assets', 'Total Assets'
                    , 'Total Liabilities', 'Net Sales', "Prev. Yr. Net Sales", 'Gross Profit', "Amortization & Depreciation", "Operating Profit",
                  "Total Interest Expense"  ,"User-Defined Time Period (optional)", 'Financial Statement Only EDF']]

# %%
dfdivide['Risk Calc Model'].unique()
# Out:
# array(['North America Large Firm', nan, 'United States',
#        'Emerging Markets', 'Mexico', 'Canada', 'Europe Large Firm',
#        'Germany', 'Spain', 'Australia', 'United Kingdom', 'China',
#        'Italy'], dtype=object)

# %%
with pd.ExcelWriter('Mexico930.xlsx') as writer:
   # Emergingmax.to_excel(writer, sheet_name='Emerging')
    Mexicoinput.to_excel(writer, sheet_name='Mexico')
    MexicosCSV.to_excel(writer, sheet_name='CSV')

# %%
dfdivide['Total Current Liabilities']=dfdivide['Current Liabilities']
#dfdivide['Prev. Yr. Total Current Liabilities']=df['Prev. Yr. Liabilities']
dfdivide['Total Interest Expense']=dfdivide['Interest Expense']
dfdivide['Total Current Assets']=dfdivide['Current Assets']

# %%
NorthAmericaLarge=pd.DataFrame()

NorthAmericaLarge=dfdivide[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash & Securities','Prev. Yr. Cash & Securities', 'Total Current Assets', 'Prev. Yr. Total Current Assets','Total Assets', 'Prev. Yr. Total Assets','Short Term Debt','Prev. Yr. Short Term Debt','Total Current Liabilities','Prev. Yr. Current Total Liabilities',
                            'Long Term Debt', 'Prev. Yr. Long Term Debt', 'Sales', 'Prev. Yr. Sales', 'Operating Profit', 'Amortization and Depreciation', 
                    'Interest Expense', 'Net Income', 'Prev. Yr. Net Income', 'Industry Classification','Industry Definition', "User-Defined Time Period (optional)", 'Financial Statement Only EDF', 'Risk Calc Model 2.0', "FYE Date", "Current Date"]]

NorthAmericaLarge1=NorthAmericaLarge[NorthAmericaLarge['Risk Calc Model 2.0']=="North America Large Firm"]
NorthAmerica2=NorthAmericaLarge1.copy()
NorthAmerica2['Current Date - Year']=((pd.datetime.now().year)-1)
NorthAmerica3=NorthAmericaLarge1.copy()
NorthAmerica3['Current Date - Year']=((pd.datetime.now().year)-2)
NorthAmerica4=NorthAmericaLarge1.copy()
NorthAmerica2['Current Date - Year']=((pd.datetime.now().year)-1)
NorthAmerica5=NorthAmericaLarge1.copy()
NorthAmerica12=NorthAmericaLarge1.append(NorthAmerica2, ignore_index=True)
NorthAmerica123=NorthAmerica12.append(NorthAmerica3,ignore_index=True)
NorthAmerica1234=NorthAmerica123.append(NorthAmerica4,ignore_index=True)
NorthAmerica=NorthAmerica1234.append(NorthAmerica5,ignore_index=True)
NorthAmericainput=NorthAmerica[['Obligor Name', 'Obligor Key', 'Statement Date - Year', 'Statement Date - Month', 'Current Date - Year' 
                     , 'Current Date - Month', 'Cash & Securities','Prev. Yr. Cash & Securities', 'Total Current Assets', 'Prev. Yr. Total Current Assets','Total Assets', 'Prev. Yr. Total Assets','Short Term Debt','Prev. Yr. Short Term Debt','Total Current Liabilities','Prev. Yr. Current Total Liabilities',
                            'Long Term Debt', 'Prev. Yr. Long Term Debt', 'Sales', 'Prev. Yr. Sales', 'Operating Profit', 'Amortization and Depreciation', 
                    'Interest Expense', 'Net Income', 'Prev. Yr. Net Income', 'Industry Classification','Industry Definition', "User-Defined Time Period (optional)", 'Financial Statement Only EDF', 'Risk Calc Model 2.0', "FYE Date", "Current Date"]]

# %%
with pd.ExcelWriter('North America.xlsx') as writer:
   # Emergingmax.to_excel(writer, sheet_name='Emerging')
    Mexicoinput.to_excel(writer, sheet_name='Mexico')
    MexicoCSV.to_excel(writer, sheet_name='CSV')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-478468ccc599> in <module>
#       2    # Emergingmax.to_excel(writer, sheet_name='Emerging')
#       3     Mexicoinput.to_excel(writer, sheet_name='Mexico')
# ----> 4     MexicoCSV.to_excel(writer, sheet_name='CSV')
#
# NameError: name 'MexicoCSV' is not defined

# %%
with pd.ExcelWriter('NorthAmerica0920__.xlsx') as writer:
   # Emergingmax.to_excel(writer, sheet_name='Emerging')
    NorthAmerica.to_excel(writer, sheet_name='North America Input CSV')

# %%
Australias=dfdivide[['obligorName', 'entityIdentifier', 'financialStatementDate', 'asOfDate','cash' 
                     , 'totalAssets','totalAssetsPreviousYear','totalAccountsPayable' ,'totalCurrentLiabilities', 'totalLiabilities','totalLiabilitiesPreviousYear',
                      'totalSales', 'totalSalesPreviousYear',  'totalOperatingProfit', 'totalAmortizationAndDepreciation',
                     'totalInterestExpense', 'netIncome','primaryIndustryClassification','primaryIndustry',"pdTerm", 'isTTC', 'Risk Calc Model', "Datadate", 'Statement Date - Month','Statement Date - Year'
                    ,'Max FYE Date', 'Current Mapped Date', 'Delete Line?']]
Australia1=Australias[Australias['Risk Calc Model']=="Australia"]


Australia2=Australia1.copy()
Australia2['Current Date - Year']=((pd.datetime.now().year)-1)
Australia3=Australia2.copy()
Australia2['Current Date - Year']=((pd.datetime.now().year)-2)
Australia4=Australia3.copy()
Australia4['Current Date - Year']=((pd.datetime.now().year)-3)
Australia5=Australia4.copy()
Australia5['Current Date - Year']=((pd.datetime.now().year)-4)
Australia6=Australia4.copy()
Australia6['Current Date - Year']=((pd.datetime.now().year)-5)
Australia12=Australia5.append(Australia2, ignore_index=True)
Australia123=Australia12.append(Australia3,ignore_index=True)
Australia1234=Australia123.append(Australia4,ignore_index=True)
Australia12345=Australia1234.append(Australia5, ignore_index=True)
Australia=Australia12345.append(Australia6,ignore_index=True)
Australiacsv=Australia[['obligorName', 'entityIdentifier', 'financialStatementDate', 'asOfDate','cash' 
                     , 'totalAssets','totalAssetsPreviousYear','totalAccountsPayable' ,'totalCurrentLiabilities', 'totalLiabilities','totalLiabilitiesPreviousYear',
                      'totalSales', 'totalSalesPreviousYear',  'totalOperatingProfit', 'totalAmortizationAndDepreciation',
                     'totalInterestExpense', 'netIncome','primaryIndustryClassification','primaryIndustry',"pdTerm", 'isTTC',  'Statement Date - Month','Statement Date - Year'
                    ,'Max FYE Date', 'Current Mapped Date', 'Delete Line?']]
Australiainput=Australia[['obligorName', 'entityIdentifier', 'financialStatementDate', 'asOfDate','cash' 
                     , 'totalAssets','totalAssetsPreviousYear','totalAccountsPayable' ,'totalCurrentLiabilities', 'totalLiabilities','totalLiabilitiesPreviousYear',
                      'totalSales', 'totalSalesPreviousYear',  'totalOperatingProfit', 'totalAmortizationAndDepreciation',
                     'totalInterestExpense', 'netIncome','primaryIndustryClassification','primaryIndustry',"pdTerm", 'isTTC']]

# %%
with pd.ExcelWriter('Australia930.xlsx') as writer:
   # Emergingmax.to_excel(writer, sheet_name='Emerging')
    Australiacsv.to_excel(writer, sheet_name=' csv')
    Australiainput.to_excel(writer, sheet_name='Australia')

# %%
Australiamax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3070 entries, 0 to 3069
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   obligorName                       3070 non-null   object
#  1   entityIdentifier                  3070 non-null   int64
#  2   financialStatementDate            3070 non-null   datetime64[ns]
#  3   asOfDate                          3070 non-null   object
#  4   cash                              3070 non-null   float64
#  5   totalAssets                       3070 non-null   float64
#  6   totalAssetsPreviousYear           3030 non-null   float64
#  7   totalAccountsPayable              3070 non-null   float64
#  8   totalCurrentLiabilities           3070 non-null   float64
#  9   totalLiabilities                  3070 non-null   float64
#  10  totalLiabilitiesPreviousYear      2970 non-null   float64
# ...

# %%
Australias.rename(index={0:'obligorName', 1:'entityIdentifier'})
# Out:
#      Obligor Name  Obligor Key   Datadate  Statement Date - Month  \
# 69         Stated    999983093 2019-12-31                      12
# 72         Stated    685057921 2015-05-31                       5
# 77         Stated    596321812 2016-09-30                       9
# 78         Stated    596321812 2020-09-27                       9
# 81         Stated    596321812 2017-10-01                      10
# ...           ...          ...        ...                     ...
# 8784       Stated   1000054154 2019-12-31                      12
# 8785       Stated   1000054154 2020-12-31                      12
# 8786       Stated   1000055514 2020-12-31                      12
# 8787       Stated   1000055642 2020-12-31                      12
# 8788       Stated    999862929 2019-12-31                      12
#
#               Cash Current Date - Month          Cash  Total Assets  \
# 69    2.814548e+03                   06  2.814548e+03  1.553538e+07
# ...

# %%
df['purchase_date'].to_numpy().astype('datetime64[M]'

# %%
#remove entires where max statement year is older than 2019
df16=df15[(df15['Statement Date - Year']>=2019)]

# %%
with pd.ExcelWriter('consolidated FAW 06242022_.xlsx') as writer:
    dfdivide.to_excel(writer, sheet_name='Consolidated FAW')

# %%
with pd.ExcelWriter('Aus and North America 06242022.xlsx') as writer:
    Australia.to_excel(writer, sheet_name='Australia')
    NorthAmerica.to_excel(writer, sheet_name='North America Large Firm')

# %%
with pd.ExcelWriter('Australiainput') as writer:
    Australiamax.to_excel(writer,sheet_name='Australia')

# %%
with pd.ExcelWriter('Aus Arranged.xlsx') as writer:
    Australiamax.to_excel(writer, sheet_name='Arrange')
